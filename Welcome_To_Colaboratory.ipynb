# %% [markdown]
# <a href="https://colab.research.google.com/github/Naradasumouli/Chaabi_Assignment/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics


# !pip install yolov8


# !pip install ultralytics


# !pip install roboflow


# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UMZdT1IsdFvuCQ9EbnEE")
project = rf.workspace("moulivenkat").project("project_pid")
dataset = project.version(1).download("yolov8")
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.7/78.2 GB disk)
#
# OS                  Linux-6.1.58+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.20GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.7.0.72>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.1.0+cu121>=1.8.0
# torchvision         ✅ 0.16.0+cu121>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data='/content/project_PID-1/data.yaml' epochs=100 imgsz=640
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 302MB/s]
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/project_PID-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68136087 parameters, 0 gradients, 257.5 GFLOPs
# val: Scanning /content/project_PID-1/valid/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100% 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:03<00:00,  1.69s/it]
#                    all         26         79      0.798      0.637      0.712      0.438
#            3 Way Valve         26          6      0.621      0.167      0.325      0.224
#            4 Way Valve         26          5          1      0.582      0.633      0.435
#            Angle Valve         26          6      0.903      0.667      0.767       0.46
#             Ball Valve         26          5      0.855        0.8      0.962      0.633
#        Butterfly Valve         26         10      0.679        0.5      0.519      0.313
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/project_PID-1/test/images save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68136087 parameters, 0 gradients, 257.5 GFLOPs
#
# image 1/17 /content/project_PID-1/test/images/09_jpeg.rf.4098fde925cef54c2ad27dcb62717d10.jpg: 640x640 (no detections), 75.5ms
# image 2/17 /content/project_PID-1/test/images/104_png.rf.f25f918ca6bc346d426ee7a1f1c2aee1.jpg: 640x640 1 Gate Valve, 62.2ms
# image 3/17 /content/project_PID-1/test/images/121_png.rf.52d184bb8c37649d0be66e3eae0c30d8.jpg: 640x640 (no detections), 52.3ms
# image 4/17 /content/project_PID-1/test/images/12_png.rf.4b4e3ebb4ce71ada7f8e52d73d496f58.jpg: 640x640 2 3 Way Valves, 1 Butterfly Valve, 1 Globe Valve, 53.3ms
# image 5/17 /content/project_PID-1/test/images/136_jpg.rf.91a956263add55ccb2fcd72fd75ada31.jpg: 640x640 1 Butterfly Valve, 1 Control Gate Valve, 53.5ms
# ...

# %%
import glob
from IPython.display import Image,display
for image_path in glob.glob (f'/content/runs/detect/predict/*jpg'):
    display(Image(filename=image_path,height=600))
    print('\n')

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/34.jpeg save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68136087 parameters, 0 gradients, 257.5 GFLOPs
#
# image 1/1 /content/34.jpeg: 512x640 1 Angle Valve, 1 Ball Valve, 2 Butterfly Valves, 1 Check Valve, 1 Control Gate Valve, 1 Control Globe Valve, 1 Gate Valve, 2 Globe Valves, 1 Needle Valve, 1 Plug Valve, 110.5ms
# Speed: 3.7ms preprocess, 110.5ms inference, 538.4ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
